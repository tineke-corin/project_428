# %% [markdown]
# <a href="https://colab.research.google.com/github/tineke-corin/project_428/blob/add_notebook/COSC428_project_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -Rf project_428

# %%
# !git clone https://github.com/tineke-corin/project_428
# Out:
# Cloning into 'project_428'...
# remote: Enumerating objects: 132, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 132 (delta 17), reused 18 (delta 9), pack-reused 79 (from 1)
# Receiving objects: 100% (132/132), 5.11 MiB | 12.02 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
# !git pull --rebase
# Out:
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 5 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 1.16 KiB | 1.16 MiB/s, done.
# From https://github.com/tineke-corin/project_428
#    3ac013a..6b7dc0a  main              -> origin/main
#  * [new branch]      missing_import_os -> origin/missing_import_os
# Updating 3ac013a..6b7dc0a
# Fast-forward
#  evaluation/pipeline_speed.py | 1 +
#  1 file changed, 1 insertion(+)

# %%
# Set up poetry and install dependencies
# !pip install poetry

# Change to the project directory
# %cd project_428

# Install project dependencies using poetry
# !poetry install
# Out:
# Streaming output truncated to the last 5000 lines.
#   - Installing yarl (1.23.0)
#   - Installing urllib3 (2.6.3)
#   - Installing wheel (0.47.0)
#   - Installing yarl (1.23.0)
#   - Installing triton (3.6.0): Downloading... 58%
#   - Installing urllib3 (2.6.3)
#   - Installing wheel (0.47.0)
#   - Installing yarl (1.23.0)
#   - Installing urllib3 (2.6.3)
#   - Installing wheel (0.47.0)
#   - Installing yarl (1.23.0)
#   - Installing triton (3.6.0): Downloading... 60%
#   - Installing urllib3 (2.6.3)
#   - Installing wheel (0.47.0)
#   - Installing yarl (1.23.0)
#   - Installing nvidia-cusparselt-cu13 (0.8.0): Downloading... 80%
#   - Installing nvidia-nccl-cu13 (2.28.9): Downloading... 60%
#   - Installing nvidia-nvshmem-cu13 (3.4.5)
#   - Installing optree (0.19.0)
#   - Installing pycparser (3.0)
#   - Installing pysocks (1.7.1)
#   - Installing rich (15.0.0)
#   - Installing setuptools (81.0.0)
#   - Installing shellingham (1.5.4)
#   - Installing six (1.17.0)
# ...

# %%
# !MPLBACKEND='' poetry run eval-total-speed --directory=test_images/many_faces
# Out:
# ...
#
# The support to run uninstalled scripts will be removed in a future release.
#
# Run `poetry install` to resolve and get rid of this message.
#
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777700786.920608    7762 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1777700790.359545    7820 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Detect + obscure average time = 620974015.2 nanoseconds (620.9740152 milliseconds)
